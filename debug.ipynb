# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

import utils.estimate_homography as util

stable, unstable = util.get_toy(1)
h = util.find_H(stable, unstable)
shape = np.shape(stable)

# %%
h
# Out:
# array([[ 9.03023986e-01, -6.10594569e-02,  1.36939027e+02],
#        [ 2.25547876e-03,  9.56475179e-01, -1.45263822e+00],
#        [-7.93031055e-05, -1.38864060e-05,  1.00000000e+00]])

# %%
plt.imshow(stable)

# %%
plt.imshow(unstable)

# %%
plt.imshow(cv2.warpPerspective(stable, h, (shape[1],shape[0])))

# %%
plt.imshow(stable)
